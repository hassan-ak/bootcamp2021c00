# %% [markdown]
# # Intro to Python

# %% [markdown]
# ## P15 Lists

# %%
names = ["Hassan","Umair","Saad","Zubair"]
print(names)
# Out:
# ['Hassan', 'Umair', 'Saad', 'Zubair']

# %%
names[0]
# Out:
# 'Hassan'

# %%
names[-1]
# Out:
# 'Zubair'

# %%
names[0] = "Ali"
names
# Out:
# ['Ali', 'Umair', 'Saad', 'Zubair']

# %%
names[0:3]
# Out:
# ['Ali', 'Umair', 'Saad']

# %% [markdown]
# ## P16 List Methods

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers.append(6)

# %%
numbers
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
numbers.insert(0,-1)

# %%
numbers
# Out:
# [-1, 1, 2, 3, 4, 5, 6]

# %%
numbers.remove(3)
numbers
# Out:
# [-1, 1, 2, 4, 5, 6]

# %%
numbers.clear()
numbers
# Out:
# []

# %%
numbers = [1,2,3,4,5]
print(1 in numbers)
print(10 in numbers)
# Out:
# True
# False

# %%
len(numbers)
# Out:
# 5

# %% [markdown]
# ## P17 For Loops

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
for i in numbers:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 0
while i < len(numbers):
    print(numbers[i])
    i = i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## P18 The range() Function

# %%
range(5)
# Out:
# range(0, 5)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5,10):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
for i in range(5,20,2):
    print(i)
# Out:
# 5
# 7
# 9
# 11
# 13
# 15
# 17
# 19

# %% [markdown]
# ## P19 Tuples

# %%
numbers = (1,2,3,1,2,3,3)
numbers
# Out:
# (1, 2, 3, 1, 2, 3, 3)

# %%
numbers.count(3)
# Out:
# 3

# %%
numbers.index(2)
# Out:
# 1
