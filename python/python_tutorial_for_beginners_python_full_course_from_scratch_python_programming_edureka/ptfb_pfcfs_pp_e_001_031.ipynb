# %% [markdown]
# # Python Tutorial For Beginners | Python Full Course From Scratch | Python Programming | Edureka

# %% [markdown]
# #### P001:- Agenda for the session
# * Introduction to python
# * Sequence and File operations
# * Functions and OOPs
# * Working to Numpy and Pandas
# * Data Visulization
# * Data Manuplation
# * Web Maps
# * Computer visoon using OpenCV

# %% [markdown]
# #### P002:- Introduction to Python
# * Why Python
#     * Simple and easy to learn
#     * Free and open source
#     * High level language
#     * Portable
#     * Supports different programming paradigm
#     * Extensible

# %% [markdown]
# #### P003:- Who is using Python
# * Youtube
# * Google
# * Dropbox
# * Resberipy
# * Bittorrent
# * Nasa
# * NSA
# * Netflix

# %% [markdown]
# #### P004:- Python Applications
# * Web scraping
# * Testing
# * Web Development
# * Data Analysis

# %% [markdown]
# #### P005:- Python Market Trends

# %% [markdown]
# #### P006:- Python Installation

# %% [markdown]
# #### P007:- Python IDE & Interpreter

# %% [markdown]
# #### P008:- Executing Code in Python

# %% [markdown]
# #### P009:- Comments and Literals

# %%
# This is a single line comment

"""
This is multiple line code
we can comment all of it
It is simple
"""
# Out:
# '\nThis is multiple line code\nwe can comment all of it\nIt is simple\n'

# %% [markdown]
# #### P010:- Indentation

# %% [markdown]
# #### P011:- Python Code Execution

# %% [markdown]
# #### P012:- Hello World Program Using Python

# %%
print("Hello world")
print("Hello world")
print("Hello to Python")
print("Happy learning \nWellcome ")
# Out:
# Hello world
# Hello world
# Hello to Python
# Happy learning
# Wellcome

# %% [markdown]
# #### P013:- Variables

# %%
a = 10
b = "Hassan"
print(a,b)
# Out:
# 10 Hassan

# %%
x,y,z = 10,20,30
print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %% [markdown]
# #### P014:- Identifiers
# * lowercase
# * start with a to z or _
# * can't start with a number
# * class starts with Upercase

# %% [markdown]
# #### P015:- Data Types
# * Mutable
#     * Lists
#     * Dict.
#     * Set
# * Immutable
#     * numbers
#     * strings
#     * tuples

# %% [markdown]
# #### P016:- Immutable Data Types
# * numbers
# * string
# * tuples

# %% [markdown]
# #### P017:- Numeric Data Type
# * numbers
#     * int
#     * float
#     * complex
#     * can be represted in
#         * Binary
#         * Octal
#         * Hexa

# %%
a = 10
b = 20
c = a+b
print("a = ", a)
print("b = ", b)
print("c = ", c)
print("Type of a = ", type(a))
print("Type of b = ", type(b))
print("Type of c = ", type(c))
# Out:
# a =  10
# b =  20
# c =  30
# Type of a =  <class 'int'>
# Type of b =  <class 'int'>
# Type of c =  <class 'int'>

# %% [markdown]
# #### P018:- Strings

# %%
a = "Hassan Ali Khan"
print(a)
print(type(a))
# Out:
# Hassan Ali Khan
# <class 'str'>

# %% [markdown]
# #### P019:- Tuples

# %%
t = (1,2,3,4,5)
print(t)
type(t)
# Out:
# (1, 2, 3, 4, 5)
# tuple

# %%
t[0]
# Out:
# 1

# %% [markdown]
# #### P020:- Mutable Data Type
#  * List
#  * Dict
#  * Sets

# %% [markdown]
# #### P21:- Lists

# %%
a = [1,2,3.2,4,"Hassan"]
print(a)
# Out:
# [1, 2, 3.2, 4, 'Hassan']

# %%
a[2]
# Out:
# 3.2

# %%
a[3]="Hello"

# %%
a
# Out:
# [1, 2, 3.2, 'Hello', 'Hassan']

# %%
b = [[1,2,3],4,"Hassan",(10,9,8)]
b
# Out:
# [[1, 2, 3], 4, 'Hassan', (10, 9, 8)]

# %%
b[0][2]
# Out:
# 3

# %% [markdown]
# #### P22 Dictionaries

# %%
a = {'Age':24,'Name':"Hassan Ali Khan"}
a
# Out:
# {'Age': 24, 'Name': 'Hassan Ali Khan'}

# %%
a['Age']
# Out:
# 24

# %% [markdown]
# #### P23 Sets

# %%
a = {1,2,3,3,4,5,5}
a
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# #### P24 Python Operators
# * Arithmetic
# * Assignment
# * Comparison
# * Logical
# * Bitwise
# * Identity
# * Membership

# %% [markdown]
# #### P25 Arithmetic Operator

# %%
a = 29
b = 27
a+b
# Out:
# 56

# %%
a-b
# Out:
# 2

# %%
a*b
# Out:
# 783

# %%
a/b
# Out:
# 1.0740740740740742

# %%
a%b
# Out:
# 2

# %%
a**b
# Out:
# 3053134545970524535745336759489912159909

# %%
a//b
# Out:
# 1

# %% [markdown]
# #### P26 Assignment Operator
# * a = a+b => a +=b
# * -
# * *
# * /
# * `**`
# * //

# %% [markdown]
# #### P27 Comparison Operator
# * ==
# * !=
# * `>`
# * <
# * `>=`
# * <=

# %% [markdown]
# #### P28 Logical Operators
# * and gives lowest value
# * or gives highest value

# %% [markdown]
# #### P29 Bitwise Operator
# * &
# * |
# * ^
# * ¬
# * `<<`
# * `>>`

# %% [markdown]
# #### P30 Identity Operator

# %%
print(4 is 5)
# Out:
# False

# %%
print(4 is not 5)
# Out:
# True

# %% [markdown]
# #### P31 MemberShip Operator
#  * in
#  * not in
