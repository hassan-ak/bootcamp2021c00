# %% [markdown]
# # Intro to Python

# %% [markdown]
# ## P1 Introduction

# %% [markdown]
# ## P2 What You Can Do With Python

# %% [markdown]
# ## P3 Your First Python Program

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## P4 Variables

# %%
age = 28
print("age = ", age)
# Out:
# age =  28

# %%
age = 30
print("age = ", age)
# Out:
# age =  30

# %%
price = 19.95
print("price = ", price)
# Out:
# price =  19.95

# %%
first_name = "Hassan Ali"
print("first_name = ", first_name)
# Out:
# first_name =  Hassan Ali

# %%
is_online = False
print("is_online = ", is_online)
# Out:
# is_online =  False

# %%
patient_name = "John Smith"
patient_age = 20
is_new_patient = True
print("patient_name = ", patient_name)
print("patient_age = ", patient_age)
print("is_new_patient", is_new_patient)
# Out:
# patient_name =  John Smith
# patient_age =  20
# is_new_patient True

# %% [markdown]
# ## P5 Receiving Input

# %%
name = input("What is your name? ")
print("Hello " + name)
# Out:
# What is your name? Hassan
# Hello Hassan

# %% [markdown]
# ## P6 Type Conversion

# %%
birth_year = input("Enter Your birth year")
age  = 2020 - int(birth_year)
print(age)
# Out:
# Enter Your birth year1992
# 28

# %%
first_number = float(input("Enter fitst number"))
second_number = float(input("Enter second number"))
sum_of_numbers = first_number + second_number
print("Sum = " + str(sum_of_numbers))
# Out:
# Enter fitst number10.2
# Enter second number13
# Sum = 23.2

# %%
# float()
# int()
# bool()
# str()

# %% [markdown]
# ## P7 Strings

# %%
course = "Python for Beginners"
print(course)
print(course.upper())
print(course.lower())
print((course.find('for')))
print(course.replace("for", "4"))
print('for' in course)
# Out:
# Python for Beginners
# PYTHON FOR BEGINNERS
# python for beginners
# 7
# Python 4 Beginners
# True

# %% [markdown]
# ## P8 Arithmetic Operators

# %%
print(10+3)
print(10-3)
print(10*3)
print(10/3)
print(10//3)
print(10 % 3)
print(10**3)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
x = 10
x = x + 3
print(x)
# Out:
# 13

# %%
y = 20
y += 3
print(y)
# Out:
# 23

# %% [markdown]
# ## P9 Operator Precedence

# %%
z = 10 + 3 * 2
print(z)
# Out:
# 16

# %%
z = (10 + 3) * 2
print(z)
# Out:
# 26

# %% [markdown]
# # P10 Comparison Operators

# %%
x = 3 > 2
print(x)
# Out:
# True

# %%
# >
# <
# <=
# >=
# ==
# !=
